# %%
import sys 
sys.path.append('E:\VS code projects\crypto-analysis')
import matplotlib.pyplot as plt
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

from src.data_fetcher import CryptoDataFetcher
print("Modules imported successfully")
# Out:
# Modules imported successfully

# %%
fetcher = CryptoDataFetcher()
bitcoin = fetcher.get_historical_data('bitcoin', 365)
print("Data fetched successfully")
bitcoin.head()
# Out:
# fetching 365 days of data for bitcoin...
# ✅ Successfully fetched 365 days of data!
# Data fetched successfully
# Price              Close          High           Low          Open  \
# Ticker           BTC-USD       BTC-USD       BTC-USD       BTC-USD
# Date
# 2024-10-31  70215.187500  72662.312500  69590.500000  72335.046875
# 2024-11-01  69482.468750  71559.015625  68779.703125  70216.898438
# 2024-11-02  69289.273438  69867.351562  69033.718750  69486.023438
# 2024-11-03  68741.117188  69361.656250  67482.523438  69296.382812
# 2024-11-04  67811.507812  69433.179688  66803.648438  68742.132812
#
# Price            Volume
# Ticker          BTC-USD
# Date
# 2024-10-31  40627912076
# 2024-11-01  49989795365
# 2024-11-02  18184612091
# 2024-11-03  34868307655
# 2024-11-04  41184819348

# %%
bitcoin.shape
print("start date:", bitcoin.index[0])
print("end date:", bitcoin.index[-1])

print(bitcoin['Close'].describe())
plt.figure(figsize=(14,7))
plt.plot(bitcoin['Close'], label='Close Price')
plt.title('Bitcoin Close Price')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend()
plt.show()
# Out:
# start date: 2024-10-31 00:00:00
# end date: 2025-10-30 00:00:00
# Ticker        BTC-USD
# count      365.000000
# mean    101526.481978
# std      12201.810141
# min      67811.507812
# 25%      94339.492188
# 50%     103191.085938
# 75%     111033.921875
# max     124752.531250
